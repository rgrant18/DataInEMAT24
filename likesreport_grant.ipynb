# %% [markdown]
# # Likes Report
# ## Chris Grant
# ## 9-13-24
#
# The source of the Instagram data being created would be me, the user of that account. The data is created once the interaction with said media is recorded. This data is created to serve the user and Meta. The user would like to go back and see posts they have liked and Meta would like to keep track of that for their own records too. It can serve more purposes for Meta due to profiting off of targeted advertisements. This data may be reliable to the user because they can agree that those actions, whether it is a like or a comment, is really that user. Meta benefits off of this too to see who their most popular accounts are so they can potentially advertise to their users.

# %%
import json
import pandas as pd
import matplotlib as plt

# %%
path = r"C:\Users\chris\Downloads\instagram-christophergrantt1-2024-09-12-ima8zG1J\your_instagram_activity\likes\liked_posts.json"
with open(path) as j:
    likes = json.load(j)

# %%
likes.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
likes['likes_media_likes']
# Out:
# [{'title': 'pubity',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C_VWHntTW39/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1725191264}]},
#  {'title': 'bitchings',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C7sY6YmPRV_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1724728330}]},
#  {'title': 'knowyourwhisky',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C84XH8zpVdV/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1724725968}]},
#  {'title': 'ali_hasan216',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C_Dt6iNpoIy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1724585711}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C93ToG9xGW9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1722003739}]},
#  {'title': 'dinomike_design',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C9K1s1tPPLA/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1721832088}]},
#  {'title': 'zachfurman',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C9OKcVMBqwg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1720578981}]},
#  {'title': 'pdinger00',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C9LrmYQuNj9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1720550123}]},
#  {'title': 'bringatrailer_wagons',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C8pJDZcMGrQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719499642}]},
#  {'title': 'islamic_post_1111',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6s79L1Nrgp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719259401}]},
#  {'title': 'vlasov_mishk',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3dsbrAqrPA/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719259318}]},
#  {'title': 'seth_kinstle',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C68LLWwNzy-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258975}]},
#  {'title': 'jugknight7714',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C685qMKMCLb/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258961}]},
#  {'title': 'streetboxing216_president',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5lzt0sO45J/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258948}]},
#  {'title': '1rakeshkushwah353',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C7mFE9DomaH/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258922}]},
#  {'title': 'lilcumtism',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C512vaSOjWV/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258906}]},
#  {'title': 'seth_kinstle',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C8Nr3uYg7oP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258872}]},
#  {'title': 'snacklys',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C77s6Iso5ct/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258800}]},
#  {'title': 'stevlanc',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C8OCzeOiAwC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719258747}]},
#  {'title': 'thanatoys',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7uWmFtC_MQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719152710}]},
#  {'title': 'esperborzoi',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C8KDnstp1k4/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719090660}]},
#  {'title': 'bro.hornsby',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C8Op0wON2Ar/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1719090629}]},
#  {'title': 'taurusun333',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C8bCsWTOcF-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718854558}]},
#  {'title': 'tonyusetoeatcheeseburgers',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C790ylapLAq/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718553884}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C8NRSoNyL0y/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718392242}]},
#  {'title': 'mothcub_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7j1ryWtmCv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718388968}]},
#  {'title': 'rawrszn',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C8BZEzesG3p/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718288582}]},
#  {'title': 'limbanizwf',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C7mWULosXqs/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718238168}]},
#  {'title': 'golden_frog_inn',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7wtutIIudt/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1718237928}]},
#  {'title': 'thisjess.cooks',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6eY4VGx_KC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1717544470}]},
#  {'string_list_data': [{'href': 'https://www.instagram.com/p/C7CQlu0gNmU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1717544175}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7uyE2FNBzO/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1717422876}]},
#  {'title': 'nolanprinty',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7cn1SqOhQm/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716831729}]},
#  {'title': 'gshock_us',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7YLTt-O_NT/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716610736}]},
#  {'title': 'haebokka_',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5AdKTXyU53/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716596907}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7WiVpatT5c/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716596798}]},
#  {'title': 'carsology.tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C7FoLGUpq5k/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716299276}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7Mc4vCN5A3/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716257698}]},
#  {'title': 'seth_kinstle',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C7KtqqQLVpy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716236621}]},
#  {'title': 'foonetworkk',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3oNI3Px-Rw/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716046261}]},
#  {'title': 'deadboylife',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C7GUT9hO-xo/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1716044717}]},
#  {'title': 'sadderlizards',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6RZiwcRr73/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715954299}]},
#  {'title': 'paige_on_a_page',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6O3cMNLAIV/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715940822}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C69Gb4cAtOE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715876291}]},
#  {'title': 'fuck.court',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C696RaWPjs0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715730919}]},
#  {'title': 'chahbazjilani',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5RNndXtOxS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715481278}]},
#  {'title': 'midnite_tremors',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6b1ZP6rcez/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715263572}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6t0lE4xoI5/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715263564}]},
#  {'title': 'toyota_jp',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6OOUmzSMWc/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715173373}]},
#  {'title': 'mynomadgirlfriend',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6kW4QPNFKA/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715173320}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6sJoLSLSPF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715136816}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6q4amRR_60/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715091897}]},
#  {'title': 'teamspeeddemon',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5HcRAlv9FQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715021832}]},
#  {'title': 'mendo.the.vizsla',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3llLiks6-m/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715020100}]},
#  {'title': 'mygalleryofinterests',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6Mid1yuIa1/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715020056}]},
#  {'title': 'conner_omalley_',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6ogfwPxCoq/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715019915}]},
#  {'title': 'thegoodhypeofficial',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5Zo1XnPBiX/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1715005968}]},
#  {'title': 'mendo.the.vizsla',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6hGXyXAeSR/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714961503}]},
#  {'title': 'eatloaded',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3Q5ccPO-L3/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714947571}]},
#  {'title': 'supercarsfor.sale',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6dIyLeugO-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714945985}]},
#  {'title': 'chrt_keithape',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C6liyywJIC1/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714945704}]},
#  {'title': 'billymurphyart',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5agUW-oRVp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714916100}]},
#  {'title': 'cars',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6M73rOS4_r/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714905140}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6fEtrLpz85/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714779888}]},
#  {'title': 'junkyard.dave',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5ruyENsjn9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714517467}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6ZYXXOPArg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714517029}]},
#  {'title': 'kyle_beaudette',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C57FfaaxdHp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714316402}]},
#  {'title': 'shoebill_mania',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5vfonBPTbK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714316325}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6O-amPLZkA/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714316274}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6RcV98tEQU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714316042}]},
#  {'title': 'howitfeelstochewfivegum',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C55iRV8uanj/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714315814}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C6Rpy_tORvp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714244411}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4qzlHxKcXu/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714151065}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5ghPAQMS59/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714151025}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C51ESsmMGpt/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714151003}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C56M0musOkC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714150993}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5jGCeyRCmX/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714086747}]},
#  {'title': 'enii_draws',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5-FywnPylf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714076209}]},
#  {'title': 'mcfriendy',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5tZM-mRqsE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1714010019}]},
#  {'title': 'swanlives',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3dJI4aLMLz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713892895}]},
#  {'title': 'artwood.ig',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3AVvguR1mQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713703440}]},
#  {'title': 'chippythedogbooks',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5o2Leev2-c/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713428037}]},
#  {'title': 'hellkattt_501',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C50v3GuO6xG/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713316188}]},
#  {'title': 'childrensillustratorsart',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5JleGLq2ra/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713299015}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C51VOq6u2s2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713295809}]},
#  {'title': 'supreme_leaks_news',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5x5erOqAfh/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1713226056}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5lRjiGMJ2W/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712961310}]},
#  {'title': 'adultswim',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5qkMS0uIDf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712961180}]},
#  {'title': 'conner_omalley_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5oObUXOBzP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712934154}]},
#  {'title': 'deadboylife',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5lGxA3uR9W/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712840863}]},
#  {'title': 'aidan_banner',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5jqZ46Ott0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712706595}]},
#  {'title': 's.iwata9247',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C06uJtnPfWz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712669820}]},
#  {'title': 'poetikflakko',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5bj6P0Jf_B/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712511846}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5dLMv1vl_F/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712510714}]},
#  {'title': 'loveandcrafted',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cqep8EDAi19/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712490312}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5WdjFxs6NE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712309872}]},
#  {'title': 'fakenewsnetwork',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5TciBercq_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712301478}]},
#  {'title': 'kiplines',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4urgzPyxd9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712245792}]},
#  {'title': 'shiftinglanes',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C5CbmoKtGpD/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712153106}]},
#  {'title': 'maximustribe',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4YbMYGAT_0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712139382}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5G_PmCvsc8/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1712106835}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5FE-c-sGv-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711978472}]},
#  {'title': 'kingjames',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/VWRYCviTM_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711852010}]},
#  {'title': 'safely_endangered',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5EO35KiJQF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711727618}]},
#  {'title': 'taurusun333',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5FBURKvC2p/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711673094}]},
#  {'title': 'mtrent47',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C5CQkdBvEXl/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711581256}]},
#  {'title': 'pure_mentality',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4_Ft19ujDj/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711539867}]},
#  {'title': 'legiqn',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C48nqWAuwGa/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711455116}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C4uvh2qPF9Y/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711113363}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4yI_VmrQfO/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711044682}]},
#  {'title': 's.iwata9247',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4shnljveOp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1711024473}]},
#  {'title': 'mtrent47',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4oEtY8xpLq/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1710704778}]},
#  {'title': 'that_blue_g87',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CbPnQfSL7kC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1710602191}]},
#  {'title': 'that_blue_g87',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3zBII-MSSb/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1710602182}]},
#  {'title': 'that_blue_g87',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4jWJl7xSQw/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1710602175}]},
#  {'title': 'bethanypontius3676',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4MpS7vN_5X/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709917459}]},
#  {'title': 'richforever',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C4JCojTrw1C/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709826857}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C4L4BkROJOS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709756756}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3UpQsJPquX/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709738066}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C2rjPvAvyrF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709737601}]},
#  {'title': 'camscott_wild',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C2kdGWZImRY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709309205}]},
#  {'title': 'wildliferescuers',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C1LmzAxr41u/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709228960}]},
#  {'title': 'thecliffs_hockinghills',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3BNCVgPn5D/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709228914}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C38G6BzRkCA/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709228307}]},
#  {'title': 'swankybear',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3TF99ioTdP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709224519}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C377e8QL0s6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1709224045}]},
#  {'title': 'fasterliving',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3vSXylINX8/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708982802}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3kN-VeP0jo/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708889645}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3mwgqAvvzQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708546635}]},
#  {'title': 'thatwhiteguy242',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3k38cnut_f/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708462245}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3lPactuEYn/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708462211}]},
#  {'title': 'fuck.court',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3eVxiJrnn6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708443667}]},
#  {'title': 'homood_h',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C3YBr8eNYa4/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708371348}]},
#  {'title': 'zachfurman',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3gd3STusyY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708311359}]},
#  {'title': 'briccbaby',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3eJr_7x55Y/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708224030}]},
#  {'title': 'bethanypontius3676',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3dmIVEMXS3/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708219496}]},
#  {'title': 'taurusun333',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3ZDxXrI9z8/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1708050472}]},
#  {'title': 'jusreign',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3RNICzx2W-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707862842}]},
#  {'title': 'supremenewyork',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3Pu-M0Lqkl/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707756525}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3KJzRCsVUi/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707684656}]},
#  {'title': 'lexususa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2h4lj4M_Cz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707666777}]},
#  {'title': 'bsbcc_japan',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C16pRLZPGpU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707488051}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C3F3jQVor_E/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707424808}]},
#  {'title': 'mercedesyilmazlar',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C2RqxgYtvpV/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707405713}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2_7xpCMYf_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707402306}]},
#  {'title': 'launch.mode',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C249Bx5uknz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707230995}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2-niMuOdK0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707163178}]},
#  {'title': 'harleyplays',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C267A-5OynS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1707133097}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2vKzUFOoqM/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706648033}]},
#  {'title': 'milesperhr',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C2m6JfuLIWU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706539335}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2qIML_S4n2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706480007}]},
#  {'title': 'rdbla',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C0PC5OzLj7K/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706423231}]},
#  {'title': 'jontaffer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2nKqOYRfhS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706388774}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2iSuneu28a/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706212733}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2hwro0sMI8/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706199159}]},
#  {'title': 'c_sellers1',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2cwpH0OCG2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1706032522}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C2SpEy5xqkK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1705715015}]},
#  {'title': 'dadocesaro',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CzjCiEPIoqs/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704935215}]},
#  {'title': 'classiccarvoyage',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1R2p9MRWbc/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704935209}]},
#  {'title': 'hondaprojason',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C1KcaGKLi7m/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704932386}]},
#  {'title': 'fuck.court',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C17xK_ryLVu/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704929731}]},
#  {'title': 'mahdiyarsaberi',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C1KKAa7MvGQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704907583}]},
#  {'title': 'stellantisna',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C17CYADgxmw/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704904631}]},
#  {'title': 'finland',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C10eI-kpWd9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704817411}]},
#  {'title': 'mansory.middle.east',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0jAAEhpjYW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704732458}]},
#  {'title': 'mansory.middle.east',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cy6Bk8SKYqJ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704732325}]},
#  {'title': 'pixel.package',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CsqD5rGgiZf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704722974}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C10MSCbLKzw/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704721583}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1wiMJZr9VU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704573112}]},
#  {'title': 'poetikflakko',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1q4H3pOKLy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704369867}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1qZfuXM9nv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704342111}]},
#  {'title': 'justinsbmws',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C0KMKNEpSBg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704293198}]},
#  {'title': 'chinamac',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1mecPgrjdm/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704205679}]},
#  {'title': 'thrashermag',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1klumYykVD/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704152581}]},
#  {'title': 'dunlaphollowcabins',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C0huWd5PgIh/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704044388}]},
#  {'title': 'stellantisna',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C1aacjCiDLC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1704044203}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cy8WivSM25M/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703952414}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C1ZgGZuM8yr/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703951880}]},
#  {'title': 'fuck.court',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1VAQZMPVTU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703943738}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1dmqgCtvWc/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703943664}]},
#  {'title': 'adultswim',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1W-qF2MaZO/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703708505}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1R48SUJShC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703556498}]},
#  {'title': 'andystriner_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1SEPgBOFbR/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703531014}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1HzuWjLg3A/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703177040}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1CtGhiLovY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703173621}]},
#  {'title': '_esauer_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1FIJktO_Ea/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703088210}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1AqfJ5Ocdm/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703015165}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C1C8PfUPCtW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1703014086}]},
#  {'title': 'pubity',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0uixMmLsVd/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702922138}]},
#  {'title': 'jusreign',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C07Me4qx0M0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702753445}]},
#  {'title': 'conner_omalley_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C01irpNOfPd/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702571468}]},
#  {'title': 'dougdemuro',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0zVrtPpQHU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702492603}]},
#  {'title': '1320video',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0PeqJCvTYR/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702398486}]},
#  {'title': 'pdinger00',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0uW0ooOvge/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702329495}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0aJZmvMxSU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702177777}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0h-rZoMidi/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702172794}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0l_orPI57S/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702051467}]},
#  {'title': 'toybarncars',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0mP_yHOhAn/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1702050723}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0fIOlzyTwn/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701908863}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0fPE2Juf28/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701815235}]},
#  {'title': 'usacrime',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C0eleKyuT-u/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701800208}]},
#  {'title': 'conner_omalley_',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/C0el_8bOi75/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701800192}]},
#  {'title': 'supremenewyork',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0eVLKOraPT/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701791078}]},
#  {'title': '55thstreet_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0bsLRxrAKi/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701700985}]},
#  {'title': 'bethanypontius3676',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0Xj-r7sjq1/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701559682}]},
#  {'title': 't.vascek22',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0NNCuQO7us/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701219008}]},
#  {'title': 'stellantisna',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0MvLlyuOfg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701195987}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0Km2nDJ7qI/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1701129047}]},
#  {'title': 'bethanypontius3676',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0DDiHxM-qX/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700939183}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/C0DIw0wJ2Bz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700888122}]},
#  {'title': 'bringatrailer_wagons',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz9MTwerv6r/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700706193}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz91S_hpVhM/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700706130}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz2upeYL4XK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700694895}]},
#  {'title': 'dougdemuro',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz9UM3ZJ_iO/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700693310}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz66OzCSGVA/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700676010}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz9F0RUJzMi/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700674583}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz1acvPIOAy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700600466}]},
#  {'title': 'interlockshorts',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cz44G70RCWy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700575037}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzyrMTvsfYG/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700344148}]},
#  {'title': 'cargurus',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Czw1cKqOkIK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700258265}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CztnwMcrcHE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700166891}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzruvpsPDYO/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700100795}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Czo58Yqyn_b/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1700063077}]},
#  {'title': 'rocarstv',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Czly5-Hppu5/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699943710}]},
#  {'title': 'supremenewyork',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CzjbJexLF_R/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699942845}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Czl2DtpIOmm/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699891352}]},
#  {'title': 'bloodyosiris',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzkJ35uMJ8X/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699878443}]},
#  {'title': 'thomaschhay2018',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzkP3ecOaPf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699878332}]},
#  {'title': 'the.holistic.psychologist',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Czg75MgPrn2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699798457}]},
#  {'title': 'followyourlegend',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cvx9jQhAODh/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699798439}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Czg3HkqJWzU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699738486}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzeY6s5LD_z/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699722044}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Czb668Ht0tV/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699557489}]},
#  {'title': 'tunedintokyo_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CtHmSe_N9FB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699554175}]},
#  {'title': 'aoctw_st',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzbzC15OXqJ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699552469}]},
#  {'title': 'switzerland.explores',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CzYp-ZVsGAv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699552352}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzbfdSSN5bK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548502}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CuwkM48s5eh/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548492}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cx0QAs_Mn3-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548476}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cy3M6EaszW9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548455}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CzELbf0MbCB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548444}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CiDAg8sjuzu/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548434}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CgMgqfcjgWK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548419}]},
#  {'title': 'swissaround',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Ce3mTQbD6tV/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699548417}]},
#  {'title': 'theocean',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Czbjq3GuzHz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699547997}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzVCRsktJry/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699547611}]},
#  {'title': 'nicekicks',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzY_hHpuiDS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699547569}]},
#  {'title': 'nicekicks',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzZxpVjRAdw/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699543520}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CzUrqXuvT4l/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699542692}]},
#  {'title': 'adultswim',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzZWCkjsi-Y/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699471823}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzUhFm6sW3r/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699465846}]},
#  {'title': 'jontaffer',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CzZMXcQs4eR/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699465783}]},
#  {'title': 'hypebeaststyle',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzWgIr7OhK5/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699381589}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzVILn-rDr6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699372296}]},
#  {'title': 'lovesecrets.01',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyvue8rMmaf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699309465}]},
#  {'title': 'yeat',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzSSP61SASx/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699238243}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzQVF1_uCab/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699196970}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzOglAmMPKg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699107153}]},
#  {'title': 'heropon11',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzNCIoVOxW0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699059044}]},
#  {'title': 'chinamac',
#   'string_list_data': [{'href': 'https://www.instagram.com/tv/CzMI5E3rqDH/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1699036626}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzCvg3Fumza/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698951999}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzJLfwNMg5d/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698951898}]},
#  {'title': 'interlockshorts',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzIAwZoJtVE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698931908}]},
#  {'title': 'pure_mentality',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzHTJObOsNf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698875139}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzHADICs09H/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698861515}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzFqDa-Lumk/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698845801}]},
#  {'title': 'brandon_buckingham',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzEpgjlRall/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698779592}]},
#  {'title': 'highwaysarebad',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cy_cdOaxnml/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698703511}]},
#  {'title': 'taurusun333',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzCCSo3udAF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698687996}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CzAyGjxM-Ru/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698675146}]},
#  {'title': 'thrashermag',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cy0_MNIrJv9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698413350}]},
#  {'title': 'hypewhip',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyCE6p6SHDo/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698291330}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cy1lwT2BFgT/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698272714}]},
#  {'title': 'asaprocky',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyvu407LUuP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698246061}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cyz1sBKrA5C/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698242710}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyy1oumS88X/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698181036}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyy2TSkSB5i/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698180973}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyy2dGfSMqE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698180935}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyy1Yexya62/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698180800}]},
#  {'title': 'mtrent47',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyx7jEHOUII/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1698154200}]},
#  {'title': 'deserted.places',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CyrKKj4Ig5N/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697929922}]},
#  {'title': 'turbu.lence1',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cx7leMkO5KY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697929251}]},
#  {'title': 'drewdecker87',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyqYpjpu_6j/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697895343}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyoMHWsL9ui/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697879418}]},
#  {'title': 'bloodyosiris',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyjmbh5yJXx/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697667119}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyiznmkpOC2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697642248}]},
#  {'title': 'dougdemuro',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyhf121rKJE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697641703}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyiyEVVuAGm/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697641651}]},
#  {'title': 'ianconnorsrevenge',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyiPuJkLBrE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697641512}]},
#  {'title': 'deserted.places',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CybirwZsjib/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697552985}]},
#  {'title': 'supreme_leaks_news',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CygGyMoq138/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697550212}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cyea420gkZH/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697513099}]},
#  {'title': 'declan_ange',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CybTUuoOWVj/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697388399}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyaWkkaO1Ce/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697385782}]},
#  {'title': 'visitingfinland',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CyYCQOkqkwe/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697301324}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyYYnEntOlb/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697297733}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyWGjH_r1lq/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697213774}]},
#  {'title': 'usacrime',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CyV8IzzuSdS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697208918}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyQsLUornYB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697119139}]},
#  {'string_list_data': [{'href': 'https://www.instagram.com/p/CyR0QH7u1is/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697069976}]},
#  {'title': 'supreme_leaks_news',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyQcqfPq9im/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1697025170}]},
#  {'title': 'iandashgo',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyMa770OxWv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696895326}]},
#  {'title': 'zipsbarstool',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyJfETTukww/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696858729}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyH8FiLL7A2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696755106}]},
#  {'title': 'conner_omalley_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyHEB09u3Ut/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696715886}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CyGymkWRZid/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696711476}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cv7VPz0o6HU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696521584}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CwnZWmwIvMx/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696521551}]},
#  {'title': 'mansory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxSurm_JQMa/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696521527}]},
#  {'string_list_data': [{'href': 'https://www.instagram.com/p/Cx_8rXhIKyY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696470471}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxyq4TlM2lW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696411881}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cx8p7KWvOmh/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696395518}]},
#  {'title': 'chieffkeeffsossa',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cx9LF55vbqW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696384802}]},
#  {'title': 'probzzzz',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cx1iDqzywkI/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696311210}]},
#  {'title': 'nojumper',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cx6Z14sSTpt/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696285226}]},
#  {'title': 'notmushu',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cx6EfEVycqj/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696273723}]},
#  {'title': 'debobt',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cx36IS6P67X/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696212267}]},
#  {'title': 'tmz_tv',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxwViaBSsc8/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1696072172}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxwtip5sJeZ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695992096}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxvqwt6RsrP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695947966}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxvqnjdRo_b/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695924482}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxvp8Yexb-P/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695924478}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxvqro1R4IB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695924444}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxvqJaeRgyB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695924415}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxvqN94x6MT/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695924402}]},
#  {'title': 'adultswim',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxs4RvWRH0A/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695851470}]},
#  {'title': 'onlineceramics',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxtPSnJSs87/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695849514}]},
#  {'title': 'andystriner_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxscj1CuvSv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695817585}]},
#  {'title': 'destodubb',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxq0tYCSv9C/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695783345}]},
#  {'title': 'the.holistic.psychologist',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxWBPDhvcHW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695777947}]},
#  {'title': 'hellkattt_501',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CxrSbnRpJNb/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695777663}]},
#  {'title': 'ali_hasan216',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxqM4SjAFBp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695743939}]},
#  {'title': 'hypebeast',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxn1b-htNiD/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695665502}]},
#  {'title': 'motor1com',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxeAY5Hp2Tw/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695347242}]},
#  {'title': 'fake___tree',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cxa4uQvuIBq/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695227364}]},
#  {'title': 'conner_omalley_',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CxYQcB7uq_q/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695140284}]},
#  {'title': 'reallyoptimus',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CwVmYwpJEyP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1695130401}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxTV3zAOhTy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694985771}]},
#  {'title': 'adultswim',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cw7yjcZNwbT/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694871077}]},
#  {'title': 'adultswim',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/CxLmdT6uTS6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694871059}]},
#  {'title': 'cargurus',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxQRrw_uYfB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694870991}]},
#  {'title': 'bringatrailer',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxOaByDuPld/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694870740}]},
#  {'title': 'insidehistory',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxMFIOLtvk6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694808213}]},
#  {'title': 'made.in.bhm',
#   'string_list_data': [{'href': 'https://www.instagram.com/reel/Cw3HvkUR2Ac/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694735519}]},
#  {'title': 'hypedrive',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CxLZ6RXM3Qy/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1694728664}]}]

# %%
likes_df = pd.DataFrame(likes['likes_media_likes'])

# %%
likes_df['Time of Like'] = [x[0]['timestamp'] for x in likes_df['timestamp']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\data_fa24\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 likes_df['Time of Like'] = [x[0]['timestamp'] for x in likes_df['timestamp']]
#
# File ~\anaconda3\envs\data_fa24\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\data_fa24\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'timestamp'

# %% [markdown]
# I am unsure how to correct the error above. I tried multiple things to incorporate the timestamp, but could not get it to produce the true value.

# %%
likes_df.groupby('title').count().sort_values('string_list_data', ascending = False).head(10)
# Out:
#                   string_list_data  Time of Like
# title
# onlineceramics                  15            15
# bringatrailer                   13            13
# mansory                         10            10
# motor1com                       10            10
# nojumper                        10            10
# notmushu                        10            10
# mcfriendy                        9             9
# hypedrive                        9             9
# swissaround                      9             9
# chieffkeeffsossa                 9             9

# %% [markdown]
# A hypothesis I have about this data is that my liked posts will have the same accounts (or similar types) as some of my shared posts. The theoretical elements of this hypothesis are the idea that saving a post and liking a post are a similar interaction. In the head of a Meta developer, a post being saved by a user would indicate a strong like for the post. Theoretically, there would be similar posts both liked and saved by me. The statistical element of my hypothesis is that I am aware I do not use the save feature on Instagram very often. It is more likely for my hypothesis to be correct based on how small the sample size of my saved posts will be.

# %%
path = r"C:\Users\chris\Downloads\instagram-christophergrantt1-2024-09-13-UTpCIzIf\your_instagram_activity\saved\saved_posts.json"
with open(path) as j:
    saved = json.load(j)

# %%
saved.keys()
# Out:
# dict_keys(['saved_saved_media'])

# %%
saved['saved_saved_media']
# Out:
# [{'title': 'mansory',
#   'string_map_data': {'Saved on': {'href': 'https://www.instagram.com/p/Cv7VPz0o6HU/',
#     'timestamp': 1696521589}}},
#  {'title': 'mansory',
#   'string_map_data': {'Saved on': {'href': 'https://www.instagram.com/p/CxSurm_JQMa/',
#     'timestamp': 1696521526}}}]

# %%
likes_df = pd.DataFrame(likes['likes_media_likes'])

# %%
saved_df = pd.DataFrame(saved['saved_saved_media'])

# %%
saved_df
# Out:
#      title                                    string_map_data
# 0  mansory  {'Saved on': {'href': 'https://www.instagram.c...
# 1  mansory  {'Saved on': {'href': 'https://www.instagram.c...

# %% [markdown]
# I ran into another issue with my project / files. I double-checked my Instagram account, and I have way more saved posts than are listed in the JSON file. This would have made this dataframe look more tidy and provide a better sample. I originally was not sure why this was, but I realized the Instagram JSON only downloads the past YEAR of interactions :/. This makes a lot of sense considering they are storing all of that information for years on end, but I did not realize that until I double-checked my Met This dataframe shows that my hypothesis is accurate because the account "mansory" is the third most liked in the past year, and
