# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf

# %%
dataset1 = pd.read_csv('dataset-one.csv')
dataset1.head()
# Out:
#    Year  Annual Mean  Lowess (5)
# 0  1880        -0.18       -0.10
# 1  1881        -0.09       -0.14
# 2  1882        -0.11       -0.17
# 3  1883        -0.18       -0.21
# 4  1884        -0.28       -0.24

# %% [markdown]
# ## The way I will be analyzing the data in my project will be trying to prove a statistical correlation between changes in global temperatures and how concentrated the levels of methane in our atmosphere are. The statitistical correlation will be tested through a visualization of each dataset, and then comparing them. I will do this using matplotlib.

# %%
fig1, ax1 = plt.subplots()
#Creating a scatter plot below uisng dataset1's values to fill it.
#I am using 'Lowess (5) as the x value and 'Annual Mean' as the y value for the scatter plot.
ax1.scatter(dataset1['Lowess (5)'], dataset1['Annual Mean'], alpha = .3)
# Shows us our chart
plt.show()

# %% [markdown]
# ## Using matplotlib's scatterplots and other features, I will show the positive correlation between the two datasets.
